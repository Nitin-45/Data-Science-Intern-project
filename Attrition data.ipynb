# %% [markdown]
# # What is meant by employee attrition?
# What is employee attrition?
# Employee attrition is the gradual reduction in employee numbers.
# Employee attrition happens when the size of your workforce diminishes over time.
# This means that employees are leaving faster than they are hired.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv ('Attrition data.csv')
df.head(10)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
# 5           6   46        No      Travel_Rarely  Research & Development
# 6           7   28       Yes      Travel_Rarely  Research & Development
# 7           8   29        No      Travel_Rarely  Research & Development
# 8           9   31        No      Travel_Rarely  Research & Development
# 9          10   25        No         Non-Travel  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# ...

# %%
df.shape
# Out:
# (4410, 29)

# %%
df.isnull().sum()
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64

# %%
df.isnull()
# Out:
#       EmployeeID    Age  Attrition  BusinessTravel  Department  \
# 0          False  False      False           False       False
# 1          False  False      False           False       False
# 2          False  False      False           False       False
# 3          False  False      False           False       False
# 4          False  False      False           False       False
# ...          ...    ...        ...             ...         ...
# 4405       False  False      False           False       False
# 4406       False  False      False           False       False
# 4407       False  False      False           False       False
# 4408       False  False      False           False       False
# 4409       False  False      False           False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  Gender  ...  \
# 0                False      False           False          False   False  ...
# ...

# %%
df.isnull().sum().sum() # total numbers of null values
# Out:
# 111

# %%
df=df.dropna(axis=0) # by defoult axis =0 ,0 for rows and 1 for columns....

# %%
df.shape
# Out:
# (4300, 29)

# %%
df=df.drop_duplicates() # No duplicates in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4300 entries, 0 to 4408
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4300 non-null   int64
#  1   Age                      4300 non-null   int64
#  2   Attrition                4300 non-null   object
#  3   BusinessTravel           4300 non-null   object
#  4   Department               4300 non-null   object
#  5   DistanceFromHome         4300 non-null   int64
#  6   Education                4300 non-null   int64
#  7   EducationField           4300 non-null   object
#  8   EmployeeCount            4300 non-null   int64
#  9   Gender                   4300 non-null   object
#  10  JobLevel                 4300 non-null   int64
#  11  JobRole                  4300 non-null   object
#  12  MaritalStatus            4300 non-null   object
#  13  MonthlyIncome            4300 non-null   int64
# ...

# %%
df.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4300.000000  4300.000000       4300.000000  4300.000000         4300.0
# mean   2211.695116    36.926977          9.197907     2.913256            1.0
# std    1272.117692     9.146517          8.097059     1.024774            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1110.750000    30.000000          2.000000     2.000000            1.0
# 50%    2215.500000    36.000000          7.000000     3.000000            1.0
# 75%    3314.250000    43.000000         14.000000     4.000000            1.0
# max    4409.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4300.000000    4300.000000         4300.000000        4300.000000
# mean      2.066977   65059.844186            2.690000          15.210698
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Main columns is Attrition

# %% [markdown]
# # Now We Start The Visualization Part

# %% [markdown]
# #  We are find out wich factors affecting attrition

# %%
sns.countplot(x='Attrition',data=df,hue='Gender')
#sns.set(rc={'figure.figsize':(5,5)})
plt.xlabel('Attrition',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Attrition By Gender',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(hue='Attrition',y='Department',data=df,palette='CMRmap')
plt.ylabel('Department',fontsize=20)
plt.xlabel('count',fontsize=20)
plt.title('Attrition By Department',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x='PerformanceRating',hue='Attrition',data=df)
plt.xlabel('Performance Rating',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Attrition By Performance Rating',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(hue='Attrition',data=df,y='EducationField',palette='cividis')
plt.ylabel('Education Field',fontsize=20)
plt.xlabel('count',fontsize=20)
plt.title('Attrition By Education Field',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.boxplot(hue='Attrition',y='TotalWorkingYears',data=df,width=0.5,x='Department',palette='CMRmap')
plt.ylabel('Total Working Years',fontsize=20)
plt.xlabel('Department',fontsize=20)
plt.title('Attrition By Total Working Years',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(hue='Attrition',x='Age',data=df)
plt.xlabel('Age',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Attrition By Age',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(hue='Attrition',x='YearsSinceLastPromotion',data=df)
plt.xlabel('Years Since Last Promotion',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Attrition By Years Since Last Promotion',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(hue='Attrition',x='JobSatisfaction',data=df,palette='cividis')
plt.xlabel('Job Satisfaction',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Attrition By Job Satisfaction',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(hue='Attrition',data=df,x='DistanceFromHome')
#sns.set(rc={'figure.figsize':(15,5)})
plt.xlabel('Distance From Home',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Attrition By Distance From Home',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(hue='Attrition',x='BusinessTravel',data=df)
plt.xlabel('Business Travel',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Attrition By Business Travel',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x='Attrition',hue='EducationField',data=df)
plt.xlabel('Education Field',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Education Field by Attrition ',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(hue='Attrition',x='YearsAtCompany',data=df)
plt.xlabel('Years At Company',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Years At Company by Attrition ',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(hue='Attrition',x='EnvironmentSatisfaction',data=df)
plt.xlabel('Environment Satisfaction',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.title('Environment Satisfaction by Attrition ',fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # End Project
